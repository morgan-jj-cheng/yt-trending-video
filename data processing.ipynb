# %% [markdown]
# ## Load Data
# ### Download data from Kaggle
# - 0801 - 0821: download from code
# - 0822 - 0831: download manually (dont know why.....)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub
from kagglehub import KaggleDatasetAdapter
from datetime import datetime

# %%
#!pip install kaggle
#!pip install kagglehub
#!pip install kagglehub[pandas-datasets]

# %%
# set date range
start_date = datetime(2024, 8, 1)
end_date = datetime(2024, 8, 21)

# Load data
df_gaming = []
df_movies = []
df_music = []
files = ["gaming", "movies", "music"]

for cat in files:
    for date in pd.date_range(start_date, end_date):
        file_path = f"{cat}/{cat}_{date.strftime('%Y%m%d')}.csv"
        df_single = kagglehub.load_dataset(
            KaggleDatasetAdapter.PANDAS,
            "pyuser11/youtube-trending-videos-updated-daily",
            file_path
        )
        eval(f"df_{cat}").append(df_single)

# combine all df
df_gaming_0821 = pd.concat(df_gaming, ignore_index=True)
df_movies_0821 = pd.concat(df_movies, ignore_index=True)
df_music_0821 = pd.concat(df_music, ignore_index=True)
# Out:
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# C:\Users\morga\AppData\Local\Temp\ipykernel_13316\2139100597.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df_single = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\exceptions.py:66, in kaggle_api_raise_for_status(response, resource_handle)
#      65 try:
# ---> 66     response.raise_for_status()
#      67 except requests.HTTPError as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://www.kaggle.com/api/v1/datasets/view/pyuser11/youtube-trending-videos-updated-daily
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# Cell In[12], line 14
#      12     for date in pd.date_range(start_date, end_date):
#      13         file_path = f"{cat}/{cat}_{date.strftime('%Y%m%d')}.csv"
# ---> 14         df_single = kagglehub.load_dataset(
#      15             KaggleDatasetAdapter.PANDAS,
#      16             "pyuser11/youtube-trending-videos-updated-daily",
#      17             file_path
#      18         )
#      19         eval(f"df_{cat}").append(df_single)
#      21 # combine all df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\datasets.py:142, in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     131 def load_dataset(
#     132     adapter: KaggleDatasetAdapter,
#     133     # In the form of {owner_slug}/{dataset_slug} or {owner_slug}/{dataset_slug}/versions/{version_number}
#    (...)
#     139     hf_kwargs: Any = None,  # noqa: ANN401
#     140 ) -> Any:  # noqa: ANN401
#     141     warnings.warn("load_dataset is deprecated and will be removed in future version.", DeprecationWarning, stacklevel=2)
# --> 142     return dataset_load(adapter, handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query, hf_kwargs=hf_kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\datasets.py:115, in dataset_load(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     112 elif adapter is KaggleDatasetAdapter.PANDAS:
#     113     import kagglehub.pandas_datasets
# --> 115     return kagglehub.pandas_datasets.load_pandas_dataset(
#     116         handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query
#     117     )
#     118 else:
#     119     not_implemented_error_message = f"{adapter} is not yet implemented"
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\pandas_datasets.py:89, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      86 read_function = _validate_read_function(file_extension, sql_query)
#      88 # Now that everything has been validated, we can start downloading and processing
# ---> 89 filepath = dataset_download(handle, path)
#      90 try:
#      91     result = read_function(
#      92         *_build_args(read_function, filepath, sql_query),
#      93         **_build_kwargs(file_extension, pandas_kwargs),
#      94     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\datasets.py:35, in dataset_download(handle, path, force_download)
#      33 h = parse_dataset_handle(handle)
#      34 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 35 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      36 return path
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#      15 def __call__(
#      16     self, handle: T, path: Optional[str] = None, *, force_download: Optional[bool] = False
#      17 ) -> tuple[str, Optional[int]]:
#      18     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      19
#      20     Args:
#    (...)
#      27         Some cases where version number might be missing: Competition datasource, API-based models.
#      28     """
# ---> 29     path, version = self._resolve(handle, path, force_download=force_download)
#      31     # Note handles are immutable, so _resolve() could not have altered our reference
#      32     register_datasource_access(handle, version)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\http_resolver.py:107, in DatasetHttpResolver._resolve(self, h, path, force_download)
#     104 api_client = KaggleApiV1Client()
#     106 if not h.is_versioned():
# --> 107     h = h.with_version(_get_current_version(api_client, h))
#     109 dataset_path = load_from_cache(h, path)
#     110 if dataset_path and not force_download:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\http_resolver.py:290, in _get_current_version(api_client, h)
#     287     return json_response[MODEL_INSTANCE_VERSION_FIELD]
#     289 elif isinstance(h, DatasetHandle):
# --> 290     json_response = api_client.get(_build_get_dataset_url_path(h), h)
#     291     if DATASET_CURRENT_VERSION_FIELD not in json_response:
#     292         msg = f"Invalid GetDataset API response. Expected to include a {DATASET_CURRENT_VERSION_FIELD} field"
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\clients.py:139, in KaggleApiV1Client.get(self, path, resource_handle)
#     132 url = self._build_url(path)
#     133 with requests.get(
#     134     url,
#     135     headers={"User-Agent": get_user_agent()},
#     136     auth=self._get_auth(),
#     137     timeout=(DEFAULT_CONNECT_TIMEOUT, DEFAULT_READ_TIMEOUT),
#     138 ) as response:
# --> 139     kaggle_api_raise_for_status(response, resource_handle)
#     140     self._check_for_version_update(response)
#     141     return response.json()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\exceptions.py:106, in kaggle_api_raise_for_status(response, resource_handle)
#      97     message = (
#      98         f"{response.status_code} Client Error."
#      99         "\n\n"
#    (...)
#     102         "Please make sure you specified the correct resource identifiers."
#     103     )
#     105 # Default handling
# --> 106 raise KaggleApiHTTPError(message, response=response) from e
#
# KaggleApiHTTPError: 404 Client Error.
#
# Resource not found at URL: https://www.kaggle.com/datasets/pyuser11/youtube-trending-videos-updated-daily
# Please make sure you specified the correct resource identifiers.

# %%
#df_trial = pd.read_csv("data/gaming/gaming_20240822.csv")

# from 0822 - 0831
start_date = datetime(2024, 8, 22)
end_date = datetime(2024, 8, 31)

# save dfs into their own category
df_dict = {
    "gaming":[], 
    "movies":[],
    "music":[]
}

files = ["gaming", "movies", "music"]
for name in files:
    for date in pd.date_range(start_date, end_date):
        link = f"data/{name}/{name}_{date.strftime('%Y%m%d')}.csv"
        df_single = pd.read_csv(link)
        df_dict[name].append(df_single)
#print(df_dict)

# combine all df
df_gaming_0831 = pd.concat(df_dict["gaming"], ignore_index=True)
df_movies_0831 = pd.concat(df_dict["movies"], ignore_index=True)
df_music_0831 = pd.concat(df_dict["music"], ignore_index=True)

# %%
# combine 0821 and 0831 data
df_gaming = pd.concat([df_gaming_0821, df_gaming_0831], ignore_index=True)
df_movies = pd.concat([df_movies_0821, df_movies_0831], ignore_index=True)
df_music = pd.concat([df_music_0821, df_music_0831], ignore_index=True)

# %%
# check length
print(len(df_gaming) == len(df_gaming_0821)+len(df_gaming_0831))
print(len(df_movies) == len(df_movies_0821)+len(df_movies_0831))
print(len(df_music) == len(df_music_0821)+len(df_music_0831))
# Out:
# True
# True
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Cleaning
# ### Gaming Dataframe

# %%
df_gaming.head()
# Out:
#                                                title  \
# 0  It's Clash Anime Season! Happy 12th Clashivers...
# 1     Brawl Stars Animation: PAINT BRAWL STARTS NOW!
# 2               NBA 2K25 | Official Gameplay Trailer
# 3  Relentlessly Hunting Down My Friends That Are ...
# 4       WE'RE SO GOOD... | Chained Together - Part 5
#
#                                          description  \
# 0  Join us in celebrating our 12th Clashiversary ...
# 1  🫧 WE'RE BRAWLING IN THE DEEP! 🫧\n\n🎨 The new P...
# 2  Pre-order now! ⬇️\nhttps://2kgam.es/3YtiOwC\n\...
# 3  Welcome back to Kill It With Fire 2 the game w...
# 4  We're so good at video games! Especially when ...
#
#               publishedDate publishedText      videoId  \
# 0  2024-08-01T18:57:43.567Z  12 hours ago  aE10HERgL-4
# 1  2024-08-01T19:03:43.567Z  11 hours ago  RJw3Y-3EBFo
# 2  2024-08-01T19:39:43.567Z   5 hours ago  qx0A921z8mA
# 3  2024-08-01T17:57:43.567Z  22 hours ago  jexy_g3l8tc
# 4  2024-08-01T17:51:43.567Z  23 hours ago  AmF6xoVAVI8
#
#                                   videoUrl     channelName  \
# 0  https://youtube.com/watch?v=aE10HERgL-4  Clash of Clans
# 1  https://youtube.com/watch?v=RJw3Y-3EBFo     Brawl Stars
# 2  https://youtube.com/watch?v=qx0A921z8mA          NBA 2K
# 3  https://youtube.com/watch?v=jexy_g3l8tc          SMii7Y
# 4  https://youtube.com/watch?v=AmF6xoVAVI8      Markiplier
#
#                   channelId                         channelUrl  \
# 0  UCD1Em4q90ZUK2R5HKesszJg  https://youtube.com/@ClashOfClans
# 1  UCooVYzDxdwTtGYAkcPmOgOw    https://youtube.com/@BrawlStars
# 2  UCYAJjqIukwm4r3GHEpJDhVw         https://youtube.com/@nba2k
# 3  UCzXwjTI6c6mVn6oui_p6oiw        https://youtube.com/@SMii7Y
# 4  UC7_YxT-KID8kRbqZo7MyscQ    https://youtube.com/@markiplier
#
#                                           thumbnails    views  \
# 0  [{'quality': 'maxres', 'url': 'https://i.ytimg...  3014088
# 1  [{'quality': 'maxres', 'url': 'https://i.ytimg...  3165597
# 2  [{'quality': 'maxres', 'url': 'https://i.ytimg...    70549
# 3  [{'quality': 'maxres', 'url': 'https://i.ytimg...  1057349
# 4  [{'quality': 'maxres', 'url': 'https://i.ytimg...   681574
#
#          viewsText  duration durationText  verified  creatorOnRise  isShort
# 0  3,014,088 views        35         0:35      True          False    False
# 1  3,165,597 views        52         0:52      True          False    False
# 2     70,549 views       118         1:58      True          False    False
# 3  1,057,349 views      1272        21:12      True          False    False
# 4    681,574 views      1740        29:00      True          False    False

# %%
# structure
print(df_gaming.columns)
print(df_gaming.shape)
# Out:
# Index(['title', 'description', 'publishedDate', 'publishedText', 'videoId',
#        'videoUrl', 'channelName', 'channelId', 'channelUrl', 'thumbnails',
#        'views', 'viewsText', 'duration', 'durationText', 'verified',
#        'creatorOnRise', 'isShort'],
#       dtype='object')
# (1550, 17)

# %%
# information
print(df_gaming.info())
print(df_gaming.describe())

# missing value
print(df_gaming.isna().sum())

# duplicate value
df_gaming.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1550 entries, 0 to 1549
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1550 non-null   object
#  1   description    1546 non-null   object
#  2   publishedDate  1550 non-null   object
#  3   publishedText  1550 non-null   object
#  4   videoId        1550 non-null   object
#  5   videoUrl       1550 non-null   object
#  6   channelName    1550 non-null   object
#  7   channelId      1550 non-null   object
#  8   channelUrl     1550 non-null   object
#  9   thumbnails     1550 non-null   object
#  10  views          1550 non-null   int64
#  11  viewsText      1550 non-null   object
#  12  duration       1550 non-null   int64
#  13  durationText   1550 non-null   object
#  14  verified       1550 non-null   bool
#  15  creatorOnRise  1550 non-null   bool
#  16  isShort        1550 non-null   bool
# dtypes: bool(3), int64(2), object(12)
# memory usage: 174.2+ KB
# None
#               views      duration
# count  1.550000e+03   1550.000000
# mean   5.975984e+05   3573.383226
# std    1.145748e+06   5930.620690
# min    1.234000e+04     10.000000
# 25%    1.884875e+05    870.750000
# 50%    3.183535e+05   1558.500000
# 75%    6.133018e+05   3141.500000
# max    1.707681e+07  42900.000000
# title            0
# description      4
# publishedDate    0
# publishedText    0
# videoId          0
# videoUrl         0
# channelName      0
# channelId        0
# channelUrl       0
# thumbnails       0
# views            0
# viewsText        0
# duration         0
# durationText     0
# verified         0
# creatorOnRise    0
# isShort          0
# dtype: int64
# 0

# %%
# view 4 missing description
mask = df_gaming["description"].isna()
df_gaming[mask]
# Out:
#                                  title description             publishedDate  \
# 637    Stream ENDS IF I lose Madden 25         NaN  2024-08-13T18:38:50.846Z
# 1062                 Hold grandpa back         NaN  2024-08-22T19:51:43.001Z
# 1138                 Hold grandpa back         NaN  2024-08-23T17:45:06.386Z
# 1488  the winged hussars have returned         NaN  2024-08-30T17:46:08.868Z
#
#               publishedText      videoId  \
# 637   Streamed 15 hours ago  5RT-xjK6co8
# 1062            3 hours ago  pBkz5ccZxoU
# 1138              1 day ago  pBkz5ccZxoU
# 1488              1 day ago  dRuJM6fakMg
#
#                                      videoUrl           channelName  \
# 637   https://youtube.com/watch?v=5RT-xjK6co8            akaElectro
# 1062  https://youtube.com/watch?v=pBkz5ccZxoU  Habitual Linecrosser
# 1138  https://youtube.com/watch?v=pBkz5ccZxoU  Habitual Linecrosser
# 1488  https://youtube.com/watch?v=dRuJM6fakMg  Habitual Linecrosser
#
#                      channelId                                 channelUrl  \
# 637   UClaQTfyXUl2CR1HYx0uVnRQ            https://youtube.com/@akaElectro
# 1062  UC6ysC3YUZbjScBKZlNLrmtQ  https://youtube.com/@habitual_linecrosser
# 1138  UC6ysC3YUZbjScBKZlNLrmtQ  https://youtube.com/@habitual_linecrosser
# 1488  UC6ysC3YUZbjScBKZlNLrmtQ  https://youtube.com/@habitual_linecrosser
#
#                                              thumbnails   views  \
# 637   [{'quality': 'maxres', 'url': 'https://i.ytimg...  149511
# 1062  [{'quality': 'maxres', 'url': 'https://i.ytimg...   79615
# 1138  [{'quality': 'maxres', 'url': 'https://i.ytimg...  279826
# 1488  [{'quality': 'maxres', 'url': 'https://i.ytimg...  267320
#
#           viewsText  duration durationText  verified  creatorOnRise  isShort
# 637   149,511 views     19522      5:25:22     False          False    False
# 1062   79,615 views       160         2:40      True          False    False
# 1138  279,826 views       160         2:40      True          False    False
# 1488  267,320 views       188         3:08      True          False    False

# %%
# save as csv
#df_gaming.to_csv("data/gaming.csv", index=False)

# %% [markdown]
# ### Movies Dataframe

# %%
df_movies.head()
# Out:
#                                                title  \
# 0             Joker: Folie À Deux | Official Trailer
# 1  Captain America: Brave New World | Official Te...
# 2               Deadpool & Wolverine | Final Trailer
# 3  Gladiator II | Official Trailer (2024 Movie) -...
# 4  A COMPLETE UNKNOWN | Official Teaser | Searchl...
#
#                                          description  \
# 0  When you’re smiling, the whole world smiles wi...
# 1  Enter a brave new world.\n\nMarvel Studios' #C...
# 2  This isn’t the movie you think it is. #Deadpoo...
# 3  From director Ridley Scott, watch the new Offi...
# 4  Timothée Chalamet is Bob Dylan in A COMPLETE U...
#
#               publishedDate publishedText      videoId  \
# 0  2024-07-31T22:33:43.999Z    9 days ago  _OKAwz2MsJs
# 1  2024-07-31T10:33:43.999Z   2 weeks ago  O_A8HdCDaWM
# 2  2024-07-31T12:57:43.999Z   13 days ago  laNA2HgwYXU
# 3  2024-07-30T17:45:43.999Z   3 weeks ago  4rgYUipGJNo
# 4  2024-08-01T00:57:43.999Z    8 days ago  TcNNteP22gQ
#
#                                   videoUrl            channelName  \
# 0  https://youtube.com/watch?v=_OKAwz2MsJs  Warner Bros. Pictures
# 1  https://youtube.com/watch?v=O_A8HdCDaWM   Marvel Entertainment
# 2  https://youtube.com/watch?v=laNA2HgwYXU          Ryan Reynolds
# 3  https://youtube.com/watch?v=4rgYUipGJNo     Paramount Pictures
# 4  https://youtube.com/watch?v=TcNNteP22gQ    SearchlightPictures
#
#                   channelId                                channelUrl  \
# 0  UCjmJDM5pRKbUlVIzDYYWb6g   https://youtube.com/@WarnerBrosPictures
# 1  UCvC4D8onUfXzvjTOM-dBfEA               https://youtube.com/@marvel
# 2  UCA3-nIYWu4PTWkb6NwhEpzg      https://youtube.com/@VancityReynolds
# 3  UCF9imwPMSGz4Vq1NiTWCC7g    https://youtube.com/@paramountpictures
# 4  UCor9rW6PgxSQ9vUPWQdnaYQ  https://youtube.com/@searchlightpictures
#
#                                           thumbnails     views  \
# 0  [{'quality': 'maxres', 'url': 'https://i.ytimg...  23057474
# 1  [{'quality': 'maxres', 'url': 'https://i.ytimg...  18605168
# 2  [{'quality': 'maxres', 'url': 'https://i.ytimg...  10406325
# 3  [{'quality': 'maxres', 'url': 'https://i.ytimg...  16402050
# 4  [{'quality': 'maxres', 'url': 'https://i.ytimg...   3425568
#
#           viewsText  duration durationText  verified  creatorOnRise  isShort
# 0  23,057,474 views       171         2:51      True          False    False
# 1  18,605,168 views       109         1:49      True          False    False
# 2  10,406,325 views       122         2:02      True          False    False
# 3  16,402,050 views       190         3:10      True          False    False
# 4   3,425,568 views       113         1:53      True          False    False

# %%
# structure
print(df_movies.columns)
print(df_movies.shape)
# Out:
# Index(['title', 'description', 'publishedDate', 'publishedText', 'videoId',
#        'videoUrl', 'channelName', 'channelId', 'channelUrl', 'thumbnails',
#        'views', 'viewsText', 'duration', 'durationText', 'verified',
#        'creatorOnRise', 'isShort'],
#       dtype='object')
# (930, 17)

# %%
# information
print(df_movies.info())
print(df_movies.describe())

# missing value
print(df_movies.isna().sum())

# duplicate value
df_movies.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          930 non-null    object
#  1   description    930 non-null    object
#  2   publishedDate  930 non-null    object
#  3   publishedText  930 non-null    object
#  4   videoId        930 non-null    object
#  5   videoUrl       930 non-null    object
#  6   channelName    930 non-null    object
#  7   channelId      930 non-null    object
#  8   channelUrl     930 non-null    object
#  9   thumbnails     930 non-null    object
#  10  views          930 non-null    int64
#  11  viewsText      930 non-null    object
#  12  duration       930 non-null    int64
#  13  durationText   930 non-null    object
#  14  verified       930 non-null    bool
#  15  creatorOnRise  930 non-null    bool
#  16  isShort        930 non-null    bool
# dtypes: bool(3), int64(2), object(12)
# memory usage: 104.6+ KB
# None
#               views     duration
# count  9.300000e+02   930.000000
# mean   5.944953e+06   295.432258
# std    9.058660e+06   418.304513
# min    3.378800e+04    23.000000
# 25%    5.874420e+05   102.000000
# 50%    1.627145e+06   150.000000
# 75%    6.461906e+06   219.000000
# max    4.705197e+07  3092.000000
# title            0
# description      0
# publishedDate    0
# publishedText    0
# videoId          0
# videoUrl         0
# channelName      0
# channelId        0
# channelUrl       0
# thumbnails       0
# views            0
# viewsText        0
# duration         0
# durationText     0
# verified         0
# creatorOnRise    0
# isShort          0
# dtype: int64
# 0

# %%
# save as csv
#df_movies.to_csv("data/movies.csv", index=False)

# %% [markdown]
# ### Music Dataframe

# %%
df_music.head()
# Out:
#                                                title  \
# 0  mgk & Jelly Roll - Lonely Road (Official Music...
# 1  YTB Fatt & Lil Durk - Conspiracy V2 (Official ...
# 2  Lil Yachty & Ian - Hate Me (Official Music Video)
# 3  Post Malone ft. Luke Combs - Guy For That (Off...
# 4  Lil Scoom89 - Blood In Blood Out (Official Mus...
#
#                                          description  \
# 0  “Lonely Road” from mgk & Jelly Roll is availab...
# 1  Stream "On Zai" Now: http://ytbfatt.lnk.to/onz...
# 2  Lyrical Lemonade Presents:\nLil Yachty & Ian -...
# 3  Official “Guy For That” music video by Post Ma...
# 4  Official Video for 'Blood In Blood Out'\nDedic...
#
#               publishedDate publishedText      videoId  \
# 0  2024-08-01T05:45:43.128Z    6 days ago  b6-JNeXxN3s
# 1  2024-08-01T03:21:43.128Z    7 days ago  YbDzBpILqNY
# 2  2024-08-01T05:45:43.128Z    6 days ago  FjFPy3N2tV4
# 3  2024-08-01T05:45:43.128Z    6 days ago  b1aBzAE-IFY
# 4  2024-08-01T00:57:43.128Z    8 days ago  wBR3evySKDY
#
#                                   videoUrl       channelName  \
# 0  https://youtube.com/watch?v=b6-JNeXxN3s               mgk
# 1  https://youtube.com/watch?v=YbDzBpILqNY         YTB Fatt
# 2  https://youtube.com/watch?v=FjFPy3N2tV4  Lyrical Lemonade
# 3  https://youtube.com/watch?v=b1aBzAE-IFY       Post Malone
# 4  https://youtube.com/watch?v=wBR3evySKDY       Lil Scoom89
#
#                   channelId  \
# 0  UCUs8sGiP4avNaYNVO22INhQ
# 1  UCqfqdCqPHxgtdJ0m32obDiw
# 2  UCtylTUUVIGY_i5afsQYeBZA
# 3  UCeLHszkByNZtPKcaVXOCOQQ
# 4  UCoUaFwRR-GHowgFXfkSS_7w
#
#                                           channelUrl  \
# 0  https://youtube.com/channel/UCUs8sGiP4avNaYNVO...
# 1  https://youtube.com/channel/UCqfqdCqPHxgtdJ0m3...
# 2                https://youtube.com/@lyricalemonade
# 3  https://youtube.com/channel/UCeLHszkByNZtPKcaV...
# 4                    https://youtube.com/@LilScoom89
#
#                                           thumbnails    views  \
# 0  [{'quality': 'maxres', 'url': 'https://i.ytimg...  5682108
# 1  [{'quality': 'maxres', 'url': 'https://i.ytimg...  2652067
# 2  [{'quality': 'maxres', 'url': 'https://i.ytimg...  4064274
# 3  [{'quality': 'maxres', 'url': 'https://i.ytimg...  4246819
# 4  [{'quality': 'maxres', 'url': 'https://i.ytimg...  1394598
#
#          viewsText  duration durationText  verified  creatorOnRise  isShort
# 0  5,682,108 views       289         4:49      True          False    False
# 1  2,652,067 views       190         3:10      True          False    False
# 2  4,064,274 views       163         2:43      True          False    False
# 3  4,246,819 views       194         3:14      True          False    False
# 4  1,394,598 views       163         2:43     False          False    False

# %%
# structure
print(df_music.columns)
print(df_music.shape)
# Out:
# Index(['title', 'description', 'publishedDate', 'publishedText', 'videoId',
#        'videoUrl', 'channelName', 'channelId', 'channelUrl', 'thumbnails',
#        'views', 'viewsText', 'duration', 'durationText', 'verified',
#        'creatorOnRise', 'isShort'],
#       dtype='object')
# (930, 17)

# %%
# information
print(df_music.info())
print(df_music.describe())

# missing value
print(df_music.isna().sum())

# duplicate value
df_music.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          930 non-null    object
#  1   description    926 non-null    object
#  2   publishedDate  930 non-null    object
#  3   publishedText  930 non-null    object
#  4   videoId        930 non-null    object
#  5   videoUrl       930 non-null    object
#  6   channelName    930 non-null    object
#  7   channelId      930 non-null    object
#  8   channelUrl     930 non-null    object
#  9   thumbnails     930 non-null    object
#  10  views          930 non-null    int64
#  11  viewsText      930 non-null    object
#  12  duration       930 non-null    int64
#  13  durationText   930 non-null    object
#  14  verified       930 non-null    bool
#  15  creatorOnRise  930 non-null    bool
#  16  isShort        930 non-null    bool
# dtypes: bool(3), int64(2), object(12)
# memory usage: 104.6+ KB
# None
#               views    duration
# count  9.300000e+02  930.000000
# mean   5.452801e+06  194.792473
# std    1.096697e+07   39.137787
# min    3.964200e+04  113.000000
# 25%    7.395838e+05  164.000000
# 50%    1.845923e+06  192.000000
# 75%    4.561997e+06  220.000000
# max    8.884766e+07  355.000000
# title            0
# description      4
# publishedDate    0
# publishedText    0
# videoId          0
# videoUrl         0
# channelName      0
# channelId        0
# channelUrl       0
# thumbnails       0
# views            0
# viewsText        0
# duration         0
# durationText     0
# verified         0
# creatorOnRise    0
# isShort          0
# dtype: int64
# 0

# %%
# view 4 missing description
mask = df_music["description"].isna()
df_music[mask]
# Out:
#                      title description             publishedDate  \
# 87   DeeBaby - Malibu Baby         NaN  2024-08-03T08:08:01.217Z
# 116  DeeBaby - Malibu Baby         NaN  2024-08-04T05:45:36.024Z
# 146  DeeBaby - Malibu Baby         NaN  2024-08-05T03:20:28.435Z
# 178  DeeBaby - Malibu Baby         NaN  2024-08-06T00:55:33.869Z
#
#     publishedText      videoId                                 videoUrl  \
# 87     5 days ago  GkPBfvYJ2Ok  https://youtube.com/watch?v=GkPBfvYJ2Ok
# 116    6 days ago  GkPBfvYJ2Ok  https://youtube.com/watch?v=GkPBfvYJ2Ok
# 146    7 days ago  GkPBfvYJ2Ok  https://youtube.com/watch?v=GkPBfvYJ2Ok
# 178    8 days ago  GkPBfvYJ2Ok  https://youtube.com/watch?v=GkPBfvYJ2Ok
#
#             channelName                 channelId  \
# 87   Official DeeBabyTV  UC4Um_x-Py3W1WFdMmxACOmg
# 116  Official DeeBabyTV  UC4Um_x-Py3W1WFdMmxACOmg
# 146  Official DeeBabyTV  UC4Um_x-Py3W1WFdMmxACOmg
# 178  Official DeeBabyTV  UC4Um_x-Py3W1WFdMmxACOmg
#
#                                      channelUrl  \
# 87   https://youtube.com/@officialdeebabytv4721
# 116  https://youtube.com/@officialdeebabytv4721
# 146  https://youtube.com/@officialdeebabytv4721
# 178  https://youtube.com/@officialdeebabytv4721
#
#                                             thumbnails   views      viewsText  \
# 87   [{'quality': 'maxres', 'url': 'https://i.ytimg...  388012  388,012 views
# 116  [{'quality': 'maxres', 'url': 'https://i.ytimg...  449459  449,459 views
# 146  [{'quality': 'maxres', 'url': 'https://i.ytimg...  505105  505,105 views
# 178  [{'quality': 'maxres', 'url': 'https://i.ytimg...  564588  564,588 views
#
#      duration durationText  verified  creatorOnRise  isShort
# 87        166         2:46     False          False    False
# 116       166         2:46     False          False    False
# 146       166         2:46     False          False    False
# 178       166         2:46     False          False    False

# %%
# save as csv
#df_music.to_csv("data/music.csv", index=False)
